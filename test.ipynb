# %%
import json
from ast import literal_eval
def write_options():
    with open ('options.json', 'w') as f:
      for item in options:
        item['item_to_buy'] = {str(k): v for k, v in item['item_to_buy'].items()}
    json.dump(options, f)

def read_options():
    with open ('options.json', 'r') as f:
      obj = json.load(f)
      #print(obj)

      for item in obj:
        print(item)
        item['item_to_buy'] = {literal_eval(k): v for k, v in item['item_to_buy'].items()}

      return obj

# %%
read_options()
# Out:
# {'description': '1-1', 'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FD221', 'item_to_buy': {'(0, 0)': 1, '(1, 0)': 2, '(2, 0)': 2}, 'account': 'www111.hung@gmail.com', 'password': '777seven'}
# {'description': '1-2', 'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FJ226', 'item_to_buy': {'(0, 0)': 2, '(1, 0)': 2, '(2, 0)': 4}, 'account': 'www222.hung@gmail.com', 'password': '777seven'}
# {'description': '1-3', 'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FF237', 'item_to_buy': {'(1, 0)': 1, '(2, 0)': 2}, 'account': 'www333.hung@gmail.com', 'password': '777seven'}
# {'description': '1-4', 'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FD221', 'item_to_buy': {'(2, 0)': 3}, 'account': 'www444.hung@gmail.com', 'password': '777seven'}
# {'description': '1-5', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JA483', 'item_to_buy': {'(1, 1)': 4}, 'account': 'www555.hung@gmail.com', 'password': '777seven'}
# {'description': '1-6', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK581', 'item_to_buy': {'(0, 0)': 4, '(1, 0)': 2, '(2, 0)': 1}, 'account': 'www666.hung@gmail.com', 'password': '777seven'}
# {'description': '2-1', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO582', 'item_to_buy': {'(0, 0)': 1, '(1, 0)': 1, '(2, 0)': 1}, 'account': 'www777.hung@gmail.com', 'password': '777seven'}
# {'description': '2-2', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JG415', 'item_to_buy': {'(0, 0)': 3, '(1, 0)': 3, '(2, 0)': 6}, 'account': 'www888.hung@gmail.com', 'password': '777seven'}
# {'description': '2-3', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF412', 'item_to_buy': {'(0, 1)': 1, '(0, 2)': 1, '(1, 0)': 1, '(1, 2)': 2, '(1, 3)': 1, '(2, 0)': 1, '(4, 0)': 2, '(4, 1)': 5, '(4, 2)': 2}, 'account': 'www999.hung@gmail.com', 'password': '777seven'}
# {'description': '2-4', 'url': '', 'item_to_buy': {'(0, 0)': 3, '(1, 0)': 1, '(4, 0)': 2}, 'account': 'www1111.hung@gmail.com', 'password': '777seven'}
# {'description': '2-5', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP13JK281', 'item_to_buy': {'(0, 0)': 10, '(1, 0)': 10}, 'account': 'www2222.hung@gmail.com', 'password': '777seven'}
# {'description': '2-6', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP13JK281', 'item_to_buy': {'(0, 0)': 10, '(1, 0)': 10}, 'account': 'www3333.hung@gmail.com', 'password': '777seven'}
# {'description': '3-1', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK361', 'item_to_buy': {'(0, 0)': 10, '(1, 0)': 10, '(2, 0)': 10}, 'account': 'www4444.hung@gmail.com', 'password': '777seven'}
# {'description': '3-2', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF363', 'item_to_buy': {'(0, 0)': 3, '(1, 0)': 3, '(2, 1)': 3}, 'account': 'www5555.hung@gmail.com', 'password': '777seven'}
# {'description': '3-3', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462', 'item_to_buy': {'(0, 0)': 2, '(1, 0)': 2}, 'account': 'www6666.hung@gmail.com', 'password': '777seven'}
# {'description': '3-4', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462', 'item_to_buy': {'(0, 0)': 8}, 'account': 'www7777.hung@gmail.com', 'password': '777seven'}
# {'description': '3-5', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462', 'item_to_buy': {'(0, 0)': 8}, 'account': 'www8888.hung@gmail.com', 'password': '777seven'}
# {'description': '3-6', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK461', 'item_to_buy': {'(0, 0)': 3}, 'account': 'www9999.hung@gmail.com', 'password': '777seven'}
# {'description': '4-1', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK942', 'item_to_buy': {'(1, 0)': 20, '(2, 0)': 20, '(3, 0)': 20, '(4, 0)': 20}, 'account': 'www0000.hung@gmail.com', 'password': '777seven'}
# {'description': '4-2', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK941', 'item_to_buy': {'(1, 0)': 20, '(2, 0)': 20, '(3, 0)': 20, '(4, 0)': 20}, 'account': 'www1122.hung@gmail.com', 'password': '777seven'}
# {'description': '4-3', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK942', 'item_to_buy': {'(1, 0)': 30}, 'account': 'www3344.hung@gmail.com', 'password': '777seven'}
# {'description': '4-4', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO362', 'item_to_buy': {'(2, 0)': 20}, 'account': 'www5566.hung@gmail.com', 'password': '777seven'}
# {'description': '4-5', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO362', 'item_to_buy': {'(0, 0)': 3, '(2, 0)': 3}, 'account': 'www7788.hung@gmail.com', 'password': '777seven'}
# {'description': '4-6', 'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK361', 'item_to_buy': {'(2, 0)': 20}, 'account': 'www0101.hung@gmail.com', 'password': '777seven'}
# [{'description': '1-1',
#   'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FD221',
#   'item_to_buy': {(0, 0): 1, (1, 0): 2, (2, 0): 2},
#   'account': 'www111.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '1-2',
#   'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FJ226',
#   'item_to_buy': {(0, 0): 2, (1, 0): 2, (2, 0): 4},
#   'account': 'www222.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '1-3',
#   'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FF237',
#   'item_to_buy': {(1, 0): 1, (2, 0): 2},
#   'account': 'www333.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '1-4',
#   'url': 'https://store.isseymiyake.com/c/at_all_all/AT21FD221',
#   'item_to_buy': {(2, 0): 3},
#   'account': 'www444.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '1-5',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JA483',
#   'item_to_buy': {(1, 1): 4},
#   'account': 'www555.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '1-6',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK581',
#   'item_to_buy': {(0, 0): 4, (1, 0): 2, (2, 0): 1},
#   'account': 'www666.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-1',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO582',
#   'item_to_buy': {(0, 0): 1, (1, 0): 1, (2, 0): 1},
#   'account': 'www777.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-2',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JG415',
#   'item_to_buy': {(0, 0): 3, (1, 0): 3, (2, 0): 6},
#   'account': 'www888.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-3',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF412',
#   'item_to_buy': {(0, 1): 1,
#    (0, 2): 1,
#    (1, 0): 1,
#    (1, 2): 2,
#    (1, 3): 1,
#    (2, 0): 1,
#    (4, 0): 2,
#    (4, 1): 5,
#    (4, 2): 2},
#   'account': 'www999.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-4',
#   'url': '',
#   'item_to_buy': {(0, 0): 3, (1, 0): 1, (4, 0): 2},
#   'account': 'www1111.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-5',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP13JK281',
#   'item_to_buy': {(0, 0): 10, (1, 0): 10},
#   'account': 'www2222.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '2-6',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP13JK281',
#   'item_to_buy': {(0, 0): 10, (1, 0): 10},
#   'account': 'www3333.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-1',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK361',
#   'item_to_buy': {(0, 0): 10, (1, 0): 10, (2, 0): 10},
#   'account': 'www4444.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-2',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF363',
#   'item_to_buy': {(0, 0): 3, (1, 0): 3, (2, 1): 3},
#   'account': 'www5555.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-3',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462',
#   'item_to_buy': {(0, 0): 2, (1, 0): 2},
#   'account': 'www6666.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-4',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462',
#   'item_to_buy': {(0, 0): 8},
#   'account': 'www7777.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-5',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JF462',
#   'item_to_buy': {(0, 0): 8},
#   'account': 'www8888.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '3-6',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK461',
#   'item_to_buy': {(0, 0): 3},
#   'account': 'www9999.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-1',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK942',
#   'item_to_buy': {(1, 0): 20, (2, 0): 20, (3, 0): 20, (4, 0): 20},
#   'account': 'www0000.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-2',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK941',
#   'item_to_buy': {(1, 0): 20, (2, 0): 20, (3, 0): 20, (4, 0): 20},
#   'account': 'www1122.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-3',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP11JK942',
#   'item_to_buy': {(1, 0): 30},
#   'account': 'www3344.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-4',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO362',
#   'item_to_buy': {(2, 0): 20},
#   'account': 'www5566.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-5',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JO362',
#   'item_to_buy': {(0, 0): 3, (2, 0): 3},
#   'account': 'www7788.hung@gmail.com',
#   'password': '777seven'},
#  {'description': '4-6',
#   'url': 'https://store.isseymiyake.com/c/pl_all_all/PP21JK361',
#   'item_to_buy': {(2, 0): 20},
#   'account': 'www0101.hung@gmail.com',
#   'password': '777seven'}]
